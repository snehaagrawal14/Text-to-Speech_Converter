# %% [markdown]
# <a href="https://colab.research.google.com/github/snehaagrawal14/Text-to-Speech_Converter/blob/main/text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Text-to-Speech Converter

# %%
# installing and importing gTTS

# !pip install gTTS
from gtts import gTTS

# %%
# Text to be converted to speech
text = input("Enter text: \n")

# Create a gTTS object
tts = gTTS(text=text, lang='en')

# Save the speech as an audio file
tts.save("output.mp3")

# Play the audio file (optional)
from IPython.display import Audio
Audio("output.mp3")
# Out:
# Enter text:
# Hello! My name is Sneha Agrawal. I am pursuing B.tech in Artificial Intelligence and Data Science from GL Bajaj Group of Institutions, Mathura.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
